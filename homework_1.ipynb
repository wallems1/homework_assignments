# %% [markdown]
# # First Homework!
# ### In your groups, develop a strategy to play Rock Paper Scissors (RPS) in an iterative arena. Your strategy will be competing against other groups' contributions, as well as my own!
#
# ### You can assume that there will be many copies of your strategy in the population at any given time. Also, the number of iterations played will range between 10 and 100.
#
#
# I've provided the framework you'll need to develop and test your strategy. Let's walk through the details of it here:

# %% [markdown]
# ## Here we have a strategy that always plays Rock
# If you need a quick refresher about how classes work in Python, check out the lesson in our class github repository [here](https://github.com/zamanlh/EvolutionInSilico_Current/blob/master/Lessons/0_PythonIntro/07_Classes.ipynb).
#
# ### We'll keep track of a few things in a RPS strategy object (this is what we call an instance of a class in Object-Oriented Programing -- which is also just a fancy way of saying when we program using objects).
#
# The self that you see all over the place is just a way of telling python that each instance of the RockOnly class will have variables that it owns and that are unique to that individual object. You can see this particularly well in the `__init__` function. The underscores means this is a private function that you can't call yourself, but is used internally. In this case, `init` is used when a new object of this type is created.
#
# We'll keep track of the set of moves an individual can play, here it is just `['R', 'P', 'S']` since we're limiting ourselves to the classic Rock Paper Scissors game. We'll also store the throws this individual has made (`self.my_history`), as well as the throws its competitor made in case we want to use those to pick the next throw in the future (`self.partner_history`). And finally, we'll also record the fitness of the individual.
#
# There are a few helper functions here as well like `reset` which just clears out the organisms memory and fitness so we can start a new competition, and `reproduce` that returns a new instance of the strategy so we can easily population the world with winning strategies.
#
# ### But the main part, and the bit you'll mostly be changing, is the `play` function!
# Here we're simply always throwing the 'R' move, which is then appended to the history variable to keep track of this individual's past moves.
#
# The `play` function can be as complex as you like, and remember that you'll be compeiting with other groups' strategies, as well as your own strategy!

# %%
import numpy as np

class RockOnly:
    def __init__(self):
        self.name = "Rock Thrower"
        self.moves = ['R', 'P', 'S']
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def reset(self):
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def play(self):
        my_move = 'R'
        self.my_history.append(my_move)
        return(my_move)
        
    def update_partner_history(self, their_move):
        self.partner_history.append(their_move)
    
    def replicate(self):
        offspring = type(self)()
        return(offspring)

# %% [markdown]
# ## Just to illustrate the competition arena, I'll make `PaperOnly` and `ScissorsOnly` strategies as well.

# %%
class PaperOnly:
    def __init__(self):
        self.name = "Paper Thrower"
        self.moves = ['R', 'P', 'S']
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def reset(self):
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def play(self):
        my_move = 'P'
        self.my_history.append(my_move)
        return(my_move)
        
    def update_partner_history(self, their_move):
        self.partner_history.append(their_move)
    
    def replicate(self):
        offspring = type(self)()
        return(offspring)

class ScissorsOnly:
    def __init__(self):
        self.name = "Scissors Thrower"
        self.moves = ['R', 'P', 'S']
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def reset(self):
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def play(self):
        my_move = 'S'
        self.my_history.append(my_move)
        return(my_move)
        
    def update_partner_history(self, their_move):
        self.partner_history.append(their_move)
    
    def replicate(self):
        offspring = type(self)()
        return(offspring)

# %%
## predictable strategy

class Predictable:
    def __init__(self):
        self.name = "Predictable"
        self.moves = ['R', 'P', 'S']
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def reset(self):
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def play(self):
        # if play history is empty, initialize with S
        if len(self.my_history) == 0:
            my_move_init = np.random.choice(self.moves)
            self.my_history.append(my_move_init)
        # if last move was S, throw R    
        if self.my_history[-1] == 'S':
            #print('S-R')
            my_move = 'R'
        # if last move was R, throw P 
        if self.my_history[-1] == 'R':
            #print('R-P')
            my_move = 'P'   
        # if last move was P, throw S   
        if self.my_history[-1] == 'P':
            #print('P-S')
            my_move = 'S'
        self.my_history.append(my_move)
        return(my_move)
        
    def update_partner_history(self, their_move):
        self.partner_history.append(their_move)
    
    def replicate(self):
        offspring = type(self)()
        return(offspring)

# %%
## vengence strategy

class Vengence:
    def __init__(self):
        self.name = "Vengence"
        self.moves = ['R', 'P', 'S']
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        self.countR = 0
        self.countP = 0
        self.countS = 0
        
    def reset(self):
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def play(self):
        # if play history is empty, initialize randomly
        if len(self.my_history) == 0:
            my_move = np.random.choice(self.moves)
            self.my_history.append(my_move)
            
        # check number of moves made and fitness, throw random if condition met    
        if len(self.my_history) > 10 and self.fitness < 5:
            my_move = np.random.choice(['R','S','P']) 
        
        # if R counter is least, then throw P  
        if self.countR < self.countS and self.countR < self.countP:
            my_move = 'P'
        # if P counter is least, then throw S
        if self.countP < self.countS and self.countP < self.countR:
            my_move = 'S'   
        # if S counter is least, then throw R
        if self.countS < self.countP and self.countS < self.countR:
            my_move = 'R'
            
        # if R and P counts equal and less than S
        if self.countR == self.countP and self.countR < self.countS:
            my_move = np.random.choice(['R'])
            
        # if P and S counts equal and less than R
        if self.countP == self.countS and self.countP < self.countR:
            my_move = np.random.choice(['P'])
            
        # if S and R counts equal and less than P
        if self.countS == self.countR and self.countS < self.countP:
            my_move = np.random.choice(['S']) 
            
        # if S and R and P counts equal
        if self.countS == self.countR and self.countS == self.countP:
            my_move = np.random.choice(['R','S','P']) 
            
        self.my_history.append(my_move)
        return(my_move)
        
    def update_partner_history(self, their_move):
        if their_move == 'R':
            self.countR = self.countR + 1
        if their_move == 'S':
            self.countS = self.countS + 1
        if their_move == 'P':
            self.countP = self.countP + 1
        self.partner_history.append(their_move)
    
    def replicate(self):
        offspring = type(self)()
        return(offspring)

# %%
# winning strategy

# ACK something is buggy in this code
# also mostly just adding this to feel like I contributed something to our project, 
#  and also this bug is annoying me so if we're done and don't have anything to do 
#  we could play around with it (aka help me make it actually work:)

class Winning:
    def __init__(self):
        self.name = "Winning"
        self.moves = ['R', 'P', 'S']
        self.my_history = []
        self.partner_history = []
        self.outcomes = {'R': 0, 'S': 0, 'P': 0}
        self.fitness = 0
        
    def reset(self):
        self.my_history = []
        self.partner_history = []
        self.fitness = 0
        
    def play(self):
        num_games = len(self.my_history)
        
        if (num_games > 20):
            if (self.my_history[num_games - 1] == 'R' and self.partner_history[num_games - 1] == 'S'):
                self.outcomes['R'] += 1
            if (self.my_history[num_games - 1] == 'R' and self.partner_history[num_games - 1] == 'P'):
                self.outcomes['R'] += -1
            if (self.my_history[num_games - 1] == 'S' and self.partner_history[num_games - 1] == 'P'):
                self.outcomes['S'] += 1
            if (self.my_history[num_games - 1] == 'S' and self.partner_history[num_games - 1] == 'R'):
                self.outcomes['S'] += -1
            if (self.my_history[num_games - 1] == 'P' and self.partner_history[num_games - 1] == 'R'):
                self.outcomes['P'] += 1
            if (self.my_history[num_games - 1] == 'P' and self.partner_history[num_games - 1] == 'S'):
                self.outcomes['P'] += -1
            
            my_move = max(self.outcomes, key = self.outcomes.get)
            
        else:
            my_move_list = random.choices(['R', 'S', 'P'])
            my_move = my_move_list[0]
            
        self.my_history.append(my_move)
        return(my_move)
                
    def update_partner_history(self, their_move):
        self.partner_history.append(their_move)
    
    def replicate(self):
        offspring = type(self)()
        return(offspring)

# %% [markdown]
# # Here is the code for the RPS Arena!
# ### You shouldn't have to change any of this, but you should use it to design and test your strategies!
# Essentially, all this is doing is creating a population of different strategies that are provided, and competing every individual in the population against every other individual, and then choosing which individuals replicate proportional to their payoffs.
#
#
# I'll add a few comments within the code to help make sense of what this is doing.

# %%
from collections import Counter
import random 

class RPSPopulation:
    def __init__(self, population_size = 100):
        #This is the RPS payoff matrix we worked out in class.
        #I've made it as dictionary so I can quickly lookup
        #rewards for a given pair of throws.
        self.payoffs = {('R','R'):0, 
                        ('R','P'):-1, 
                        ('R','S'):1, 
                        ('P','R'):1, 
                        ('P','P'):0, 
                        ('P','S'):-1, 
                        ('S','R'):-1, 
                        ('S','P'):1, 
                        ('S','S'):0 }
        
        self.population = []
        self.pop_size = population_size
        self.strategies = []
        
    #This returns a dictionary of "Strategy Name": Count in the population
    def get_strategy_counts(self):
        return Counter([ind.name for ind in self.population])
    
    #This adds a strategy to the pool used to populate the arena
    def add_strategy(self, strategy):
        self.strategies.append(strategy)
    
    #Randomly pick a strategy to fill each spot in the population
    def randomly_populate(self):
        for i in range(self.pop_size):
            random_strategy = random.choice(self.strategies)
            new_individual = random_strategy()
            self.population.append(new_individual)
    
    #Compete a pair of individuals for num_iterations
    def compete(self, player1, player2, num_iterations):
        for i in range(num_iterations):
            #Get what each player throws
            throw_1 = player1.play()
            throw_2 = player2.play()
            
            #Record the other players throw in their records
            player1.update_partner_history(throw_2)
            player2.update_partner_history(throw_1)
            
            #Get the payoffs from the payoff matrix for each player
            player1_payoff = self.payoffs[(throw_1, throw_2)]
            player2_payoff = self.payoffs[(throw_2, throw_1)]
            
            #And Update their fitness
            player1.fitness += player1_payoff
            player2.fitness += player2_payoff
        
    #Compete all pairs of individuals, noting that we don't need to repeat
    #competitions since A v B is the same as B v A (we've updated both players).
    def evaluate_population(self, num_iterations):
        for i in range(self.pop_size-1):
            for j in range(i+1, self.pop_size):
                self.compete(self.population[i], self.population[j], num_iterations)        
    
    #Step forward a num_generations of competitions, updating the population
    #each generation.
    def step(self, num_iterations, num_generations=1):
        for gen in range(num_generations):
            #do the competition
            self.evaluate_population(num_iterations)
            pop_fitness = [p.fitness for p in self.population]
            
            #If we end up with all ties, we'll divide by 0 and that causes problems
            if max(pop_fitness) == min(pop_fitness):
                norm_fitness = [1 for ind in pop_fitness]
            else:
                #Lets rescale values to be positive to avoid weirdness with negative
                #weights in random.choices
                norm_fitness = [1 + 
                                (f - min(pop_fitness))/(max(pop_fitness)-min(pop_fitness)) 
                                for f in pop_fitness]
            
            #Do the sampling to pick the next population
            next_pop = random.choices(self.population, weights=norm_fitness, k=self.pop_size)
            
            #Replace each individual we picked with an offspring so we don't end up with
            #weird duplicates of the same object. This is a quark of Python, and just means
            #we're creating a new object for each new individual in the population instead of
            #creating a reference to the *same* old object. 
            for i in range(len(next_pop)):
                next_pop[i] = next_pop[i].replicate()
            self.population = next_pop
            
        #Finally, return the book keeping numbers
        return(self.get_strategy_counts())

# %% [markdown]
# ## Continuing with the demonstration, let's create an Arena with 200 individuals playing either the RockOnly, PaperOnly, or ScissorsOnly strategies.

# %%
pop = RPSPopulation(population_size=200)

#pop.add_strategy(RockOnly)
#pop.add_strategy(PaperOnly)
#pop.add_strategy(ScissorsOnly)
pop.add_strategy(Vengence)
pop.add_strategy(Predictable)


pop.randomly_populate()

# %% [markdown]
# ### We can see a messy print out of the randomly generated population.

# %%
print(pop.population)
# Out:
# [<__main__.Vengence object at 0x00000270B5286CF8>, <__main__.Predictable object at 0x00000270B5286D68>, <__main__.Vengence object at 0x00000270B5286DD8>, <__main__.Predictable object at 0x00000270B5286E80>, <__main__.Vengence object at 0x00000270B5286E10>, <__main__.Predictable object at 0x00000270B5286E48>, <__main__.Vengence object at 0x00000270B5286EB8>, <__main__.Predictable object at 0x00000270B5286F60>, <__main__.Vengence object at 0x00000270B5286EF0>, <__main__.Vengence object at 0x00000270B5286F28>, <__main__.Predictable object at 0x00000270B5286C88>, <__main__.Predictable object at 0x00000270B5286CC0>, <__main__.Vengence object at 0x00000270B5286F98>, <__main__.Vengence object at 0x00000270B5286FD0>, <__main__.Vengence object at 0x00000270B5286AC8>, <__main__.Vengence object at 0x00000270B5286B00>, <__main__.Predictable object at 0x00000270B5286A20>, <__main__.Vengence object at 0x00000270B5286A90>, <__main__.Vengence object at 0x00000270B52867F0>, <__main__.Predictable object at 0x00000270B5286828>, <__main__.Vengence object at 0x00000270B4E7BA58>, <__main__.Vengence object at 0x00000270B4E7BBE0>, <__main__.Predictable object at 0x00000270B4E7B5F8>, <__main__.Predictable object at 0x00000270B4E7BAC8>, <__main__.Vengence object at 0x00000270B4E7BCF8>, <__main__.Predictable object at 0x00000270B4E7B898>, <__main__.Vengence object at 0x00000270B4E7B8D0>, <__main__.Vengence object at 0x00000270B4E7B860>, <__main__.Vengence object at 0x00000270B4E7BEB8>, <__main__.Vengence object at 0x00000270B4E7B940>, <__main__.Predictable object at 0x00000270B4E7BD30>, <__main__.Vengence object at 0x00000270B4E7B080>, <__main__.Vengence object at 0x00000270B4E7BA90>, <__main__.Vengence object at 0x00000270B4E7B908>, <__main__.Predictable object at 0x00000270B4E7BEF0>, <__main__.Vengence object at 0x00000270B4E7BBA8>, <__main__.Predictable object at 0x00000270B4E7BB70>, <__main__.Vengence object at 0x00000270B4E7BFD0>, <__main__.Vengence object at 0x00000270B4E7BC18>, <__main__.Vengence object at 0x00000270B4E7B198>, <__main__.Vengence object at 0x00000270B4E7BF28>, <__main__.Vengence object at 0x00000270B4E7B630>, <__main__.Vengence object at 0x00000270B4E7BC88>, <__main__.Vengence object at 0x00000270B4E7BB38>, <__main__.Vengence object at 0x00000270B4E7B320>, <__main__.Vengence object at 0x00000270B4E7B9E8>, <__main__.Vengence object at 0x00000270B4E7B278>, <__main__.Vengence object at 0x00000270B4E7B240>, <__main__.Vengence object at 0x00000270B4E7B550>, <__main__.Vengence object at 0x00000270B626C160>, <__main__.Vengence object at 0x00000270B626C278>, <__main__.Vengence object at 0x00000270B626C048>, <__main__.Vengence object at 0x00000270B626C2E8>, <__main__.Predictable object at 0x00000270B626C3C8>, <__main__.Vengence object at 0x00000270B626C2B0>, <__main__.Predictable object at 0x00000270B626C400>, <__main__.Predictable object at 0x00000270B626C438>, <__main__.Vengence object at 0x00000270B626C470>, <__main__.Predictable object at 0x00000270B626C4A8>, <__main__.Vengence object at 0x00000270B626C4E0>, <__main__.Predictable object at 0x00000270B626C320>, <__main__.Vengence object at 0x00000270B626C358>, <__main__.Vengence object at 0x00000270B626C5C0>, <__main__.Vengence object at 0x00000270B626C390>, <__main__.Predictable object at 0x00000270B626C518>, <__main__.Predictable object at 0x00000270B626C630>, <__main__.Vengence object at 0x00000270B626C668>, <__main__.Predictable object at 0x00000270B626C5F8>, <__main__.Predictable object at 0x00000270B626C6D8>, <__main__.Vengence object at 0x00000270B626C6A0>, <__main__.Vengence object at 0x00000270B626C710>, <__main__.Vengence object at 0x00000270B626C550>, <__main__.Vengence object at 0x00000270B626CA90>, <__main__.Predictable object at 0x00000270B626C908>, <__main__.Predictable object at 0x00000270B626C780>, <__main__.Predictable object at 0x00000270B626C828>, <__main__.Predictable object at 0x00000270B626C588>, <__main__.Predictable object at 0x00000270B626C978>, <__main__.Venge ...

# %% [markdown]
# ## Now let's run this population for 50 generations, keeping track of the number of each strategy.

# %%
rock_paper_scissors = [[],[]]
for i in range(50):
    strategy_counts = pop.step(num_iterations=10, num_generations=1)
    #rock_paper_scissors[0].append(strategy_counts['Rock Thrower'])
    #rock_paper_scissors[1].append(strategy_counts['Paper Thrower'])
    #rock_paper_scissors[2].append(strategy_counts['Scissors Thrower'])
    rock_paper_scissors[0].append(strategy_counts['Vengence'])    
    rock_paper_scissors[1].append(strategy_counts['Predictable'])

# %% [markdown]
# ## So that we can plot the number of individuals from each strategy

# %%
from matplotlib import pyplot
pyplot.plot(np.transpose(rock_paper_scissors))
pyplot.legend(["Vengence","Predictable"])
pyplot.xlabel("Generation")
pyplot.ylabel("Num Individuals")
pyplot.show()

# %% [markdown]
# ### Why do you think we end up with all Paper after a few generations?

# %% [markdown]
# # For your group homework submission:
# ## Submit a single Jupyter Notebook or python file containing your implementation of a RPS Strategy, and some markdown or comments describing your approach.
#
# ## Each person should submit a file with the same strategy -- but include a little blurb about what you and others in your group contributed, and what you found interesting and/or struggled with during this assignment.
